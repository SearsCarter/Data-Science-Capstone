# %%
import pandas as pd
import requests
import numpy as np
import regex as re
from functools import reduce

# %%
Date = '2022-02-28'

# %%
#Turnover/Assist
url = 'https://www.teamrankings.com/ncaa-basketball/stat/assist--per--turnover-ratio?date=' + Date
html = requests.get(url).content
TurnAst = pd.read_html(html)
TurnAst = TurnAst[0]
TurnAst = TurnAst.drop(TurnAst.columns[[0,2,4,7]], axis=1)
TurnAst.rename(columns={'Home':'TurnAst_Home'}, inplace=True)
TurnAst.rename(columns={'Away':'TurnAst_Away'},inplace=True)
TurnAst.rename(columns={'Last 3':'TurnAst_Last3'},inplace=True)

#Points
url = 'https://www.teamrankings.com/ncaa-basketball/stat/points-per-game?date=' + Date
html = requests.get(url).content
Points = pd.read_html(html)
Points = Points[0]
Points = Points.drop(Points.columns[[0,2,4,7]], axis=1)
Points.rename(columns={'Home':'Points_Home'}, inplace=True)
Points.rename(columns={'Away':'Points_Away'},inplace=True)
Points.rename(columns={'Last 3':'Pts_Last3'},inplace=True)

#Average Scoring Margin
url = 'https://www.teamrankings.com/ncaa-basketball/stat/average-scoring-margin?date=' + Date
html = requests.get(url).content
Avg_Scoring_Margin = pd.read_html(html)
Avg_Scoring_Margin = Avg_Scoring_Margin[0]
Avg_Scoring_Margin = Avg_Scoring_Margin.drop(Avg_Scoring_Margin.columns[[0,2,4,7]], axis=1)
Avg_Scoring_Margin.rename(columns={'Home':'Avg_Scoring_Margin_Home'}, inplace=True)
Avg_Scoring_Margin.rename(columns={'Away':'Avg_Scoring_Margin_Away'},inplace=True)
Avg_Scoring_Margin.rename(columns={'Last 3':'Avg_Scoring_Margin_Last3'},inplace=True)

#Offensive Efficiency
url = 'https://www.teamrankings.com/ncaa-basketball/stat/offensive-efficiency?date=' + Date
html = requests.get(url).content
OffEff = pd.read_html(html)
OffEff = OffEff[0]
OffEff = OffEff.drop(OffEff.columns[[0,2,4,7]], axis=1)
OffEff.rename(columns={'Home':'OffEff_Home'}, inplace=True)
OffEff.rename(columns={'Away':'OffEff_Away'},inplace=True)
OffEff.rename(columns={'Last 3':'OffEff_Last3'},inplace=True)

#Floor%
url = 'https://www.teamrankings.com/ncaa-basketball/stat/floor-percentage?date=' + Date
html = requests.get(url).content
FloorPercent = pd.read_html(html)
FloorPercent = FloorPercent[0]
FloorPercent = FloorPercent.drop(FloorPercent.columns[[0,2,4,7]], axis=1)
FloorPercent.rename(columns={'Home':'FloorPercent_Home'}, inplace=True)
FloorPercent.rename(columns={'Away':'FloorPercent_Away'},inplace=True)
FloorPercent.rename(columns={'Last 3':'FloorPercent_Last3'},inplace=True)

#True Shooting Percent
url = 'https://www.teamrankings.com/ncaa-basketball/stat/true-shooting-percentage?date=' + Date
html = requests.get(url).content
TrueShooting = pd.read_html(html)
TrueShooting = TrueShooting[0]
TrueShooting = TrueShooting.drop(TrueShooting.columns[[0,2,4,7]], axis=1)
TrueShooting.rename(columns={'Home':'TrueShooting_Home'}, inplace=True)
TrueShooting.rename(columns={'Away':'TrueShooting_Away'},inplace=True)
TrueShooting.rename(columns={'Last 3':'TrueShooting_Last3'},inplace=True)

#Effective FG Percent
url = 'https://www.teamrankings.com/ncaa-basketball/stat/effective-field-goal-pct?date=' + Date
html = requests.get(url).content
EffFGPct = pd.read_html(html)
EffFGPct = EffFGPct[0]
EffFGPct = EffFGPct.drop(EffFGPct.columns[[0,2,4,7]], axis=1)
EffFGPct.rename(columns={'Home':'EffFGPct_Home'}, inplace=True)
EffFGPct.rename(columns={'Away':'EffFGPct_Away'},inplace=True)
EffFGPct.rename(columns={'Last 3':'EffFGPct_Last3'},inplace=True)

#Free Throw %
url = 'https://www.teamrankings.com/ncaa-basketball/stat/free-throw-pct?date=' + Date
html = requests.get(url).content
FTpct = pd.read_html(html)
FTpct = FTpct[0]
FTpct = FTpct.drop(FTpct.columns[[0,2,4,7]], axis=1)
FTpct.rename(columns={'Home':'FTpct_Home'}, inplace=True)
FTpct.rename(columns={'Away':'FTpct_Away'},inplace=True)
FTpct.rename(columns={'Last 3':'FTpct_Last3'},inplace=True)

#Free Throws Attempted Per Offensive Play
url = 'https://www.teamrankings.com/ncaa-basketball/stat/free-throw-rate?date=' + Date
html = requests.get(url).content
FT_Rate = pd.read_html(html)
FT_Rate = FT_Rate[0]
FT_Rate = FT_Rate.drop(FT_Rate.columns[[0,2,4,7]], axis=1)
FT_Rate.rename(columns={'Home':'FT_Rate_Home'}, inplace=True)
FT_Rate.rename(columns={'Away':'FT_Rate_Away'},inplace=True)
FT_Rate.rename(columns={'Last 3':'FT_Rate_Last3'},inplace=True)

#Three Pt Rate
url = 'https://www.teamrankings.com/ncaa-basketball/stat/three-point-rate?date=' + Date
html = requests.get(url).content
Three_Pt_Rate = pd.read_html(html)
Three_Pt_Rate = Three_Pt_Rate[0]
Three_Pt_Rate = Three_Pt_Rate.drop(Three_Pt_Rate.columns[[0,2,4,7]], axis=1)
Three_Pt_Rate.rename(columns={'Home':'Three_Pt_Rate_Home'}, inplace=True)
Three_Pt_Rate.rename(columns={'Away':'Three_Pt_Rate_Away'},inplace=True)
Three_Pt_Rate.rename(columns={'Last 3':'Three_Pt_Rate_Last3'},inplace=True)

#Offensive Rebounding Percentage
url = 'https://www.teamrankings.com/ncaa-basketball/stat/offensive-rebounding-pct?date=' + Date
html = requests.get(url).content
Off_RB_Pct = pd.read_html(html)
Off_RB_Pct = Off_RB_Pct[0]
Off_RB_Pct = Off_RB_Pct.drop(Off_RB_Pct.columns[[0,2,4,7]], axis=1)
Off_RB_Pct.rename(columns={'Home':'Off_RB_Pct_Home'}, inplace=True)
Off_RB_Pct.rename(columns={'Away':'Off_RB_Pct_Away'},inplace=True)
Off_RB_Pct.rename(columns={'Last 3':'Off_RB_Pct_Last3'},inplace=True)

#Defensive Rebounding Percentage
url = 'https://www.teamrankings.com/ncaa-basketball/stat/defensive-rebounding-pct?date=' + Date
html = requests.get(url).content
Def_RB_Pct = pd.read_html(html)
Def_RB_Pct = Def_RB_Pct[0]
Def_RB_Pct = Def_RB_Pct.drop(Def_RB_Pct.columns[[0,2,4,7]], axis=1)
Def_RB_Pct.rename(columns={'Home':'Def_RB_Pct_Home'}, inplace=True)
Def_RB_Pct.rename(columns={'Away':'Def_RB_Pct_Away'},inplace=True)
Def_RB_Pct.rename(columns={'Last 3':'Def_RB_Pct_Last3'},inplace=True)

#Block Percentage
url = 'https://www.teamrankings.com/ncaa-basketball/stat/block-pct?date=' + Date
html = requests.get(url).content
Block_Pct = pd.read_html(html)
Block_Pct = Block_Pct[0]
Block_Pct = Block_Pct.drop(Block_Pct.columns[[0,2,4,7]], axis=1)
Block_Pct.rename(columns={'Home':'Block_Pct_Home'}, inplace=True)
Block_Pct.rename(columns={'Away':'Block_Pct_Away'},inplace=True)
Block_Pct.rename(columns={'Last 3':'Block_Pct_Last3'},inplace=True)

#Steals Per Possesion
url = 'https://www.teamrankings.com/ncaa-basketball/stat/steals-perpossession?date=' + Date
html = requests.get(url).content
Steals_PerPoss = pd.read_html(html)
Steals_PerPoss = Steals_PerPoss[0]
Steals_PerPoss = Steals_PerPoss.drop(Steals_PerPoss.columns[[0,2,4,7]], axis=1)
Steals_PerPoss.rename(columns={'Home':'Steals_PerPoss_Home'}, inplace=True)
Steals_PerPoss.rename(columns={'Away':'Steals_PerPoss_Away'},inplace=True)
Steals_PerPoss.rename(columns={'Last 3':'Steals_PerPoss_Last3'},inplace=True)

#Turnovers Per Possession
url = 'https://www.teamrankings.com/ncaa-basketball/stat/turnovers-per-possession?date=' + Date
html = requests.get(url).content
Turn_PerPoss = pd.read_html(html)
Turn_PerPoss = Turn_PerPoss[0]
Turn_PerPoss = Turn_PerPoss.drop(Turn_PerPoss.columns[[0,2,4,7]], axis=1)
Turn_PerPoss.rename(columns={'Home':'Turn_PerPoss_Home'}, inplace=True)
Turn_PerPoss.rename(columns={'Away':'Turn_PerPoss_Away'},inplace=True)
Turn_PerPoss.rename(columns={'Last 3':'Turn_PerPoss_Last3'},inplace=True)

#Assists Per Possession
url = 'https://www.teamrankings.com/ncaa-basketball/stat/assists-per-possession?date=' + Date
html = requests.get(url).content
Ast_PerPoss = pd.read_html(html)
Ast_PerPoss = Ast_PerPoss[0]
Ast_PerPoss = Ast_PerPoss.drop(Ast_PerPoss.columns[[0,2,4,7]], axis=1)
Ast_PerPoss.rename(columns={'Home':'Ast_PerPoss_Home'}, inplace=True)
Ast_PerPoss.rename(columns={'Away':'Ast_PerPoss_Away'},inplace=True)
Ast_PerPoss.rename(columns={'Last 3':'Ast_PerPoss_Last3'},inplace=True)

#Fouls Per Possession
url = 'https://www.teamrankings.com/ncaa-basketball/stat/personal-fouls-per-possession?date=' + Date
html = requests.get(url).content
Fouls_PerPoss = pd.read_html(html)
Fouls_PerPoss = Fouls_PerPoss[0]
Fouls_PerPoss = Fouls_PerPoss.drop(Fouls_PerPoss.columns[[0,2,4,7]], axis=1)
Fouls_PerPoss.rename(columns={'Home':'Fouls_PerPoss_Home'}, inplace=True)
Fouls_PerPoss.rename(columns={'Away':'Fouls_PerPoss_Away'},inplace=True)
Fouls_PerPoss.rename(columns={'Last 3':'Fouls_PerPoss_Last3'},inplace=True)

# %%
#Defensive Points Allowed
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-points-per-game?date=' + Date
html = requests.get(url).content
Points_Allowed = pd.read_html(html)
Points_Allowed = Points_Allowed[0]
Points_Allowed = Points_Allowed.drop(Points_Allowed.columns[[0,2,4,7]], axis=1)
Points_Allowed.rename(columns={'Home':'Points_Allowed_Home'}, inplace=True)
Points_Allowed.rename(columns={'Away':'Points_Allowed_Away'},inplace=True)
Points_Allowed.rename(columns={'Last 3':'Points_Allowed_Last3'},inplace=True)

#Opponent Average Scoring Margin
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-average-scoring-margin?date=' + Date
html = requests.get(url).content
Opp_Avg_Scoring_Margin = pd.read_html(html)
Opp_Avg_Scoring_Margin = Opp_Avg_Scoring_Margin[0]
Opp_Avg_Scoring_Margin = Opp_Avg_Scoring_Margin.drop(Opp_Avg_Scoring_Margin.columns[[0,2,4,7]], axis=1)
Opp_Avg_Scoring_Margin.rename(columns={'Home':'Opp_Avg_Scoring_Margin_Home'}, inplace=True)
Opp_Avg_Scoring_Margin.rename(columns={'Away':'Opp_Avg_Scoring_Margin_Away'},inplace=True)
Opp_Avg_Scoring_Margin.rename(columns={'Last 3':'Opp_Avg_Scoring_Margin_Last3'},inplace=True)

#Defensive Efficiency
url = 'https://www.teamrankings.com/ncaa-basketball/stat/defensive-efficiency?date=' + Date
html = requests.get(url).content
Def_Eff = pd.read_html(html)
Def_Eff = Def_Eff[0]
Def_Eff = Def_Eff.drop(Def_Eff.columns[[0,2,4,7]], axis=1)
Def_Eff.rename(columns={'Home':'Def_Eff_Home'}, inplace=True)
Def_Eff.rename(columns={'Away':'Def_Eff_Away'},inplace=True)
Def_Eff.rename(columns={'Last 3':'Def_Eff_Last3'},inplace=True)

#Opponent Floor %
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-floor-percentage?date=' + Date
html = requests.get(url).content
Opp_Floor_Pct = pd.read_html(html)
Opp_Floor_Pct = Opp_Floor_Pct[0]
Opp_Floor_Pct = Opp_Floor_Pct.drop(Opp_Floor_Pct.columns[[0,2,4,7]], axis=1)
Opp_Floor_Pct.rename(columns={'Home':'Opp_Floor_Pct_Home'}, inplace=True)
Opp_Floor_Pct.rename(columns={'Away':'Opp_Floor_Pct_Away'},inplace=True)
Opp_Floor_Pct.rename(columns={'Last 3':'Opp_Floor_Pct_Last3'},inplace=True)

#Opponent Effective FG Percentage
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-effective-field-goal-pct?date=' + Date
html = requests.get(url).content
Opp_Eff_FG_Pct = pd.read_html(html)
Opp_Eff_FG_Pct = Opp_Eff_FG_Pct[0]
Opp_Eff_FG_Pct = Opp_Eff_FG_Pct.drop(Opp_Eff_FG_Pct.columns[[0,2,4,7]], axis=1)
Opp_Eff_FG_Pct.rename(columns={'Home':'Opp_Eff_FG_Pct_Home'}, inplace=True)
Opp_Eff_FG_Pct.rename(columns={'Away':'Opp_Eff_FG_Pct_Away'},inplace=True)
Opp_Eff_FG_Pct.rename(columns={'Last 3':'Opp_Eff_FG_Pct_Last3'},inplace=True)

#Opponent True Shooting %
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-true-shooting-percentage?date=' + Date
html = requests.get(url).content
Opp_TrueShooting_Pct = pd.read_html(html)
Opp_TrueShooting_Pct = Opp_TrueShooting_Pct[0]
Opp_TrueShooting_Pct = Opp_TrueShooting_Pct.drop(Opp_TrueShooting_Pct.columns[[0,2,4,7]], axis=1)
Opp_TrueShooting_Pct.rename(columns={'Home':'Opp_TrueShooting_Pct_Home'}, inplace=True)
Opp_TrueShooting_Pct.rename(columns={'Away':'Opp_TrueShooting_Pct_Away'},inplace=True)
Opp_TrueShooting_Pct.rename(columns={'Last 3':'Opp_TrueShooting_Pct_Last3'},inplace=True)

#Opponent Three Pt Rate
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-three-point-rate?date=' + Date
html = requests.get(url).content
Opp_Three_Pt_Rate = pd.read_html(html)
Opp_Three_Pt_Rate = Opp_Three_Pt_Rate[0]
Opp_Three_Pt_Rate = Opp_Three_Pt_Rate.drop(Opp_Three_Pt_Rate.columns[[0,2,4,7]], axis=1)
Opp_Three_Pt_Rate.rename(columns={'Home':'Opp_Three_Pt_Rate_Home'}, inplace=True)
Opp_Three_Pt_Rate.rename(columns={'Away':'Opp_Three_Pt_Rate_Away'},inplace=True)
Opp_Three_Pt_Rate.rename(columns={'Last 3':'Opp_Three_Pt_Rate_Last3'},inplace=True)

#Opponent Free Throws Attempted Per Offensive Play
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-free-throw-rate?date=' + Date
html = requests.get(url).content
Opp_FT_Rate = pd.read_html(html)
Opp_FT_Rate = Opp_FT_Rate[0]
Opp_FT_Rate = Opp_FT_Rate.drop(Opp_FT_Rate.columns[[0,2,4,7]], axis=1)
Opp_FT_Rate.rename(columns={'Home':'Opp_FT_Rate_Home'}, inplace=True)
Opp_FT_Rate.rename(columns={'Away':'Opp_FT_Rate_Away'},inplace=True)
Opp_FT_Rate.rename(columns={'Last 3':'Opp_FT_Rate_Last3'},inplace=True)

#Opponent Block %
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-block-pct?date=' + Date
html = requests.get(url).content
Opp_Block_Pct = pd.read_html(html)
Opp_Block_Pct = Opp_Block_Pct[0]
Opp_Block_Pct = Opp_Block_Pct.drop(Opp_Block_Pct.columns[[0,2,4,7]], axis=1)
Opp_Block_Pct.rename(columns={'Home':'Opp_Block_Pct_Home'}, inplace=True)
Opp_Block_Pct.rename(columns={'Away':'Opp_Block_Pct_Away'},inplace=True)
Opp_Block_Pct.rename(columns={'Last 3':'Opp_Block_Pct_Last3'},inplace=True)

#Opponent Steals Per Possession
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-steals-perpossession?date=' + Date
html = requests.get(url).content
Opp_Steals_PerPoss = pd.read_html(html)
Opp_Steals_PerPoss = Opp_Steals_PerPoss[0]
Opp_Steals_PerPoss = Opp_Steals_PerPoss.drop(Opp_Steals_PerPoss.columns[[0,2,4,7]], axis=1)
Opp_Steals_PerPoss.rename(columns={'Home':'Opp_Steals_PerPoss_Home'}, inplace=True)
Opp_Steals_PerPoss.rename(columns={'Away':'Opp_Steals_PerPoss_Away'},inplace=True)
Opp_Steals_PerPoss.rename(columns={'Last 3':'Opp_Steals_PerPoss_Last3'},inplace=True)

#Opponent Turnover/Assist Ratio
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-assist--per--turnover-ratio?date=' + Date
html = requests.get(url).content
Opp_AstTurn_Ratio = pd.read_html(html)
Opp_AstTurn_Ratio = Opp_AstTurn_Ratio[0]
Opp_AstTurn_Ratio = Opp_AstTurn_Ratio.drop(Opp_AstTurn_Ratio.columns[[0,2,4,7]], axis=1)
Opp_AstTurn_Ratio.rename(columns={'Home':'Opp_AstTurn_Ratio_Home'}, inplace=True)
Opp_AstTurn_Ratio.rename(columns={'Away':'Opp_AstTurn_Ratio_Away'},inplace=True)
Opp_AstTurn_Ratio.rename(columns={'Last 3':'Opp_AstTurn_Ratio_Last3'},inplace=True)

#Opponent Assists Per Possession
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-assists-per-possession?date=' + Date
html = requests.get(url).content
Opp_Ast_PerPoss = pd.read_html(html)
Opp_Ast_PerPoss = Opp_Ast_PerPoss[0]
Opp_Ast_PerPoss = Opp_Ast_PerPoss.drop(Opp_Ast_PerPoss.columns[[0,2,4,7]], axis=1)
Opp_Ast_PerPoss.rename(columns={'Home':'Opp_Ast_PerPoss_Home'}, inplace=True)
Opp_Ast_PerPoss.rename(columns={'Away':'Opp_Ast_PerPoss_Away'},inplace=True)
Opp_Ast_PerPoss.rename(columns={'Last 3':'Opp_Ast_PerPoss_Last3'},inplace=True)

#Opponent Turnovers Per Possession
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-turnovers-per-possession?date=' + Date
html = requests.get(url).content
Opp_Turn_PerPoss = pd.read_html(html)
Opp_Turn_PerPoss = Opp_Turn_PerPoss[0]
Opp_Turn_PerPoss = Opp_Turn_PerPoss.drop(Opp_Turn_PerPoss.columns[[0,2,4,7]], axis=1)
Opp_Turn_PerPoss.rename(columns={'Home':'Opp_Turn_PerPoss_Home'}, inplace=True)
Opp_Turn_PerPoss.rename(columns={'Away':'Opp_Turn_PerPoss_Away'},inplace=True)
Opp_Turn_PerPoss.rename(columns={'Last 3':'Opp_Turn_PerPoss_Last3'},inplace=True)

#Opponent Fouls Per Possession
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-personal-fouls-per-possession?date=' + Date
html = requests.get(url).content
Opp_Fouls_PerPoss = pd.read_html(html)
Opp_Fouls_PerPoss = Opp_Fouls_PerPoss[0]
Opp_Fouls_PerPoss = Opp_Fouls_PerPoss.drop(Opp_Fouls_PerPoss.columns[[0,2,4,7]], axis=1)
Opp_Fouls_PerPoss.rename(columns={'Home':'Opp_Fouls_PerPoss_Home'}, inplace=True)
Opp_Fouls_PerPoss.rename(columns={'Away':'Opp_Fouls_PerPoss_Away'},inplace=True)
Opp_Fouls_PerPoss.rename(columns={'Last 3':'Opp_Fouls_PerPoss_Last3'},inplace=True)

#Possessions Per Game
url = 'https://www.teamrankings.com/ncaa-basketball/stat/possessions-per-game?date=' + Date
html = requests.get(url).content
Poss_Per_Game = pd.read_html(html)
Poss_Per_Game = Poss_Per_Game[0]
Poss_Per_Game = Poss_Per_Game.drop(Poss_Per_Game.columns[[0,2,4,7]], axis=1)
Poss_Per_Game.rename(columns={'Home':'Poss_Per_Game_Home'}, inplace=True)
Poss_Per_Game.rename(columns={'Away':'Poss_Per_Game_Away'},inplace=True)
Poss_Per_Game.rename(columns={'Last 3':'Poss_Per_Game_Last3'},inplace=True)

#Effective Possession Rato
url = 'https://www.teamrankings.com/ncaa-basketball/stat/effective-possession-ratio?date=' + Date
html = requests.get(url).content
Eff_Poss = pd.read_html(html)
Eff_Poss = Eff_Poss[0]
Eff_Poss = Eff_Poss.drop(Eff_Poss.columns[[0,2,4,7]], axis=1)
Eff_Poss.rename(columns={'Home':'Eff_Poss_Home'}, inplace=True)
Eff_Poss.rename(columns={'Away':'Eff_Poss_Away'},inplace=True)
Eff_Poss.rename(columns={'Last 3':'Eff_Poss_Last3'},inplace=True)

#Opponent Effective Possession Ratio
url = 'https://www.teamrankings.com/ncaa-basketball/stat/opponent-effective-possession-ratio?date=' + Date
html = requests.get(url).content
Opp_Eff_Poss = pd.read_html(html)
Opp_Eff_Poss = Opp_Eff_Poss[0]
Opp_Eff_Poss = Opp_Eff_Poss.drop(Opp_Eff_Poss.columns[[0,2,4,7]], axis=1)
Opp_Eff_Poss.rename(columns={'Home':'Opp_Eff_Poss_Home'}, inplace=True)
Opp_Eff_Poss.rename(columns={'Away':'Opp_Eff_Poss_Away'},inplace=True)
Opp_Eff_Poss.rename(columns={'Last 3':'Opp_Eff_Poss_Last3'},inplace=True)

# %%
#Luck
url = 'https://www.teamrankings.com/ncaa-basketball/ranking/luck-by-other?date=' + Date
html = requests.get(url).content
Luck = pd.read_html(html)
Luck = Luck[0]
Luck = Luck.drop(Luck.columns[[0,3,4,5,6,7,8]], axis=1)
Luck.rename(columns={'Rating':'Team_Luck'},inplace=True)
Luck['Team'] = Luck['Team'].apply(lambda x: re.sub(r' \([^()]*\)', '', x))

#Strength of Schedule
url = 'https://www.teamrankings.com/ncaa-basketball/ranking/season-sos-by-other?date=' + Date
html = requests.get(url).content
SOS = pd.read_html(html)
SOS = SOS[0]
SOS = SOS.drop(SOS.columns[[0,3,4,5]], axis=1)
SOS.rename(columns={'Rating':'Team_SOS'},inplace=True)
SOS['Team'] = SOS['Team'].apply(lambda x: re.sub(r' \([^()]*\)', '', x))

#Consistency
url = 'https://www.teamrankings.com/ncaa-basketball/ranking/consistency-by-other?date=' + Date
html = requests.get(url).content
Consis = pd.read_html(html)
Consis = Consis[0]
Consis = Consis.drop(Consis.columns[[0,3,4,5,6,7,8]], axis=1)
Consis.rename(columns={'Rating':'Team_Consis'},inplace=True)
Consis['Team'] = Consis['Team'].apply(lambda x: re.sub(r' \([^()]*\)', '', x))

#First Half Rating
url = 'https://www.teamrankings.com/ncaa-basketball/ranking/first-half-by-other?date=' + Date
html = requests.get(url).content
First_Half_Rating = pd.read_html(html)
First_Half_Rating = First_Half_Rating[0]
First_Half_Rating = First_Half_Rating.drop(First_Half_Rating.columns[[0,3,4,5]], axis=1)
First_Half_Rating.rename(columns={'Rating':'Team_First_Half_Rating'},inplace=True)
First_Half_Rating['Team'] = First_Half_Rating['Team'].apply(lambda x: re.sub(r' \([^()]*\)', '', x))

#Second Half Rating
url = 'https://www.teamrankings.com/ncaa-basketball/ranking/second-half-by-other?date=' + Date
html = requests.get(url).content
Second_Half_Rating = pd.read_html(html)
Second_Half_Rating = Second_Half_Rating[0]
Second_Half_Rating = Second_Half_Rating.drop(Second_Half_Rating.columns[[0,3,4,5]], axis=1)
Second_Half_Rating.rename(columns={'Rating':'Team_Second_Half_Rating'},inplace=True)
Second_Half_Rating['Team'] = Second_Half_Rating['Team'].apply(lambda x: re.sub(r' \([^()]*\)', '', x))

#Last5
url = 'https://www.teamrankings.com/ncaa-basketball/ranking/last-5-games-by-other?date=' + Date
html = requests.get(url).content
Last5 = pd.read_html(html)
Last5 = Last5[0]
Last5 = Last5.drop(Last5.columns[[0,3,4,5]], axis=1)
Last5.rename(columns={'Rating':'Team_Last5'},inplace=True)
Last5['Team'] = Last5['Team'].apply(lambda x: re.sub(r' \([^()]*\)', '', x))

# %%
All = [TurnAst, Points, Avg_Scoring_Margin, OffEff, FloorPercent, TrueShooting, EffFGPct, FTpct, FT_Rate, Three_Pt_Rate, Off_RB_Pct, Def_RB_Pct, Block_Pct, Steals_PerPoss, Turn_PerPoss, Ast_PerPoss, Fouls_PerPoss, Points_Allowed, Opp_Avg_Scoring_Margin, Def_Eff, Opp_Floor_Pct, Opp_Eff_FG_Pct, Opp_TrueShooting_Pct, Opp_Three_Pt_Rate, Opp_FT_Rate, Opp_Block_Pct, Opp_Steals_PerPoss, Opp_AstTurn_Ratio, Opp_Ast_PerPoss, Opp_Turn_PerPoss, Opp_Fouls_PerPoss, Poss_Per_Game, Eff_Poss, Opp_Eff_Poss, Luck, SOS, Consis, First_Half_Rating, Second_Half_Rating, Last5]

# %%
Final = reduce(lambda  left,right: pd.merge(left,right,on=['Team'],
                                            how='outer'), All)
Final = Final[Final['Team'] != 'St Fran']
Final = Final[Final['Team'] != 'St. Thomas (MN)']
Final = Final[Final['Team'] != 'St. Thomas']
Final = Final[Final['Team'] != 'Miami']
Final = Final[Final['Team'] != 'Miami (FL)']
Final = Final[Final['Team'] != 'Miami (OH)']
Final = Final[Final['Team'] != 'St Fran (PA)']
Final = Final[Final['Team'] != 'St Fran (NY)']
Final = Final[Final['Team'] != 'Maryland ES']

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
for x in Final.columns:
    Final[x] = Final[x].astype(str)
    Final[x] = Final[x].str.replace('%', '')
    Final[x] = Final[x].str.replace('+', '')
    Final[x] = Final[x].str.replace('--', '0')
for x in Final.columns:
    if x != 'Team':
        Final[x] = Final[x].astype(float)

# %%
urlzz = 'https://www.teamrankings.com/ncb/scores/?date=' + Date
htmlzz = requests.get(urlzz).content
Sch = pd.read_html(htmlzz)
Games = pd.DataFrame()

# %%
len(Sch) - 18
# Out:
# 19

# %%
for i in range(19):
    Sch1 = Sch[i]
    Sch1 = Sch1[['FINAL', 'FINAL.1']]
    Sch2 = Sch1[:3]
    data = [[(Sch2['FINAL'].iloc[1]),(Sch2['FINAL'].iloc[0]), int(Sch2['FINAL.1'].iloc[1]) - int(Sch2['FINAL.1'].iloc[0]), (Sch2['FINAL'].iloc[2])]]
    df1 = pd.DataFrame(data, columns = ['Home', 'Away','Home_Pt_Diff', 'DropColumn'])
    Games = Games.append(df1)
Games = Games[Games['DropColumn'] != '(no analysis avaliable)']
Games = Games.drop('DropColumn', 1)

# %%
Games = Games[Games['Away'] != 'Miami (FL)']
Games = Games[Games['Home'] != 'Miami (FL)']
Games = Games[Games['Away'] != 'St Fran (NY)']
Games = Games[Games['Home'] != 'St Fran (NY)']
Games = Games[Games['Away'] != 'Miami (OH)']
Games = Games[Games['Home'] != 'Miami (OH)']
Games = Games[Games['Away'] != 'St Fran (PA)']
Games = Games[Games['Home'] != 'St Fran (PA)']
Games = Games[Games['Away'] != 'St. Thomas (MN)']
Games = Games[Games['Home'] != 'St. Thomas (MN)']
Games = Games[Games['Away'] != 'Maryland ES']
Games = Games[Games['Home'] != 'Maryland ES']
Games = Games[Games['Away'] != 'Bushnell']
Games = Games[Games['Home'] != 'Bushnell']
Games = Games[Games['Away'] != 'Southeastern Baptist College']
Games = Games[Games['Home'] != 'Southeastern Baptist College']
Games = Games[Games['Away'] != 'Bethesda University']
Games = Games[Games['Home'] != 'Bethesda University']
Games = Games[Games['Away'] != 'Presentation College']
Games = Games[Games['Home'] != 'Presentation College']
Games = Games[Games['Away'] != 'Mississippi College']
Games = Games[Games['Home'] != 'Mississippi College']
Games = Games[Games['Away'] != 'Lancaster Bible College']
Games = Games[Games['Home'] != 'Lancaster Bible College']
Games = Games[Games['Away'] != 'Rhodes']
Games = Games[Games['Home'] != 'Rhodes']
Games = Games[Games['Away'] != 'Clarks Summit']
Games = Games[Games['Home'] != 'Clarks Summit']
Games = Games[Games['Away'] != 'Point Park']
Games = Games[Games['Home'] != 'Point Park']
Games = Games[Games['Away'] != 'Kentucky Christian']
Games = Games[Games['Home'] != 'Kentucky Christian']
Games = Games[Games['Away'] != 'Saginaw Valley']
Games = Games[Games['Home'] != 'Saginaw Valley']
Games = Games[Games['Away'] != 'Warren Wilson']
Games = Games[Games['Home'] != 'Warren Wilson']
Games = Games[Games['Away'] != 'Fort Valley State']
Games = Games[Games['Home'] != 'Fort Valley State']
Games = Games[Games['Away'] != 'Centenary']
Games = Games[Games['Home'] != 'Centenary']
Games = Games[Games['Away'] != 'Boyce']
Games = Games[Games['Home'] != 'Boyce']
Games = Games[Games['Away'] != 'Lincoln (CA)']
Games = Games[Games['Home'] != 'Lincoln (CA)']
Games = Games[Games['Away'] != 'Our Lady of the Lake']
Games = Games[Games['Home'] != 'Our Lady of the Lake']
Games = Games[Games['Away'] != 'Dallas University']
Games = Games[Games['Home'] != 'Dallas University']
Games = Games[Games['Away'] != 'Rust College']
Games = Games[Games['Home'] != 'Rust College']
Games = Games[Games['Away'] != 'College of Saint Elizabeth']
Games = Games[Games['Home'] != 'College of Saint Elizabeth']
Games = Games[Games['Away'] != 'East Mennonite']
Games = Games[Games['Home'] != 'East Mennonite']
Games = Games[Games['Away'] != 'Jarvis Christian']
Games = Games[Games['Home'] != 'Jarvis Christian']
Games = Games[Games['Away'] != 'Edward Waters']
Games = Games[Games['Home'] != 'Edward Waters']
Games = Games[Games['Away'] != 'Schreiner']
Games = Games[Games['Home'] != 'Schriener']
Games = Games[Games['Away'] != 'Northland']
Games = Games[Games['Home'] != 'Northland']
Games = Games[Games['Away'] != 'Crown College']
Games = Games[Games['Home'] != 'Crown College']
Games = Games[Games['Away'] != 'Carver Bible College']
Games = Games[Games['Home'] != 'Carver Bible College']
Games = Games[Games['Away'] != 'Bob Jones']
Games = Games[Games['Home'] != 'Bob Jones']
Games = Games[Games['Away'] != 'Minnesota Morris']
Games = Games[Games['Home'] != 'Minnesota Morris']
Games = Games[Games['Away'] != 'Waldorf']
Games = Games[Games['Home'] != 'Waldorf']
Games = Games[Games['Away'] != 'St. Katherine']
Games = Games[Games['Home'] != 'St. Katherine']
Games = Games[Games['Away'] != 'Calvary University']
Games = Games[Games['Home'] != 'Calvary University']
Games = Games[Games['Away'] != 'Lenoir-Rhyne']
Games = Games[Games['Home'] != 'Lenoir-Rhyne']
Games = Games[Games['Away'] != 'Wiley']
Games = Games[Games['Home'] != 'Wiley']
Games = Games[Games['Away'] != 'UC Merced']
Games = Games[Games['Home'] != 'UC Merced']
Games = Games[Games['Away'] != 'North Park']
Games = Games[Games['Home'] != 'North Park']
Games = Games[Games['Away'] != 'Southwestern']
Games = Games[Games['Home'] != 'Southwestern']
Games = Games[Games['Away'] != 'Webster']
Games = Games[Games['Home'] != 'Webster']
Games = Games[Games['Away'] != 'LSU Shreveport']
Games = Games[Games['Home'] != 'LSU Shreveport']
Games = Games[Games['Away'] != 'Nyack College']
Games = Games[Games['Home'] != 'Nyack College']
Games = Games[Games['Away'] != 'Keuka College']
Games = Games[Games['Home'] != 'Keuka College']
Games = Games[Games['Away'] != 'Defiance']
Games = Games[Games['Home'] != 'Defiance']
Games = Games[Games['Away'] != 'Milligan']
Games = Games[Games['Home'] != 'Milligan']
Games = Games[Games['Away'] != 'Northwood (MI)']
Games = Games[Games['Home'] != 'Northwood (MI)']
Games = Games[Games['Away'] != 'Cal Lutheran']
Games = Games[Games['Home'] != 'Cal Lutheran']
Games = Games[Games['Away'] != 'Babson']
Games = Games[Games['Home'] != 'Babson']
Games = Games[Games['Away'] != 'Voorhees']
Games = Games[Games['Home'] != 'Voorhees']
Games = Games[Games['Away'] != 'Millersville']
Games = Games[Games['Home'] != 'Millersville']
Games = Games[Games['Away'] != 'Champion Baptist']
Games = Games[Games['Home'] != 'Champion Baptist']
Games = Games[Games['Away'] != 'Dallas Christian']
Games = Games[Games['Home'] != 'Dallas Christian']
Games = Games[Games['Away'] != 'Roosevelt']
Games = Games[Games['Home'] != 'Roosevelt']
Games = Games[Games['Away'] != 'Columbia International']
Games = Games[Games['Home'] != 'Columbia International']
Games = Games[Games['Away'] != 'East-West University']
Games = Games[Games['Home'] != 'East-West University']
Games = Games[Games['Away'] != 'Guilford']
Games = Games[Games['Home'] != 'Guilford']
Games = Games[Games['Away'] != 'SUNY-Purchase']
Games = Games[Games['Home'] != 'SUNY-Purchase']

# %%
Games.loc[(Games.Away == 'Wash State'),'Away']= 'Washington St.'
Games.loc[(Games.Away == 'Abl Christian'),'Away']= 'Abilene Christian'
Games.loc[(Games.Away == 'N Arizona'),'Away']= 'Northern Arizona'
Games.loc[(Games.Away == 'U Penn'),'Away']= 'Penn'
Games.loc[(Games.Away == 'TX El Paso'),'Away']= 'UTEP'
Games.loc[(Games.Away == 'SIU Edward'),'Away']= 'SIU Edwardsville'
Games.loc[(Games.Away == 'TN Tech'),'Away']= 'Tennessee Tech'
Games.loc[(Games.Away == 'Middle Tenn'),'Away']= 'Middle Tennessee'
Games.loc[(Games.Away == 'Neb Omaha'),'Away']= 'Nebraska Omaha'
Games.loc[(Games.Away == 'LA Tech'),'Away']= 'Louisiana Tech'
Games.loc[(Games.Away == 'S Alabama'),'Away']= 'South Alabama'
Games.loc[(Games.Away == 'NC-Wilmgton'),'Away']= 'UNC Wilmington'
Games.loc[(Games.Away == 'NW State'),'Away']= 'Northwestern St.'
Games.loc[(Games.Away == 'E Carolina'),'Away']= 'East Carolina'
Games.loc[(Games.Away == 'Detroit'),'Away']= 'Detroit Mercy'
Games.loc[(Games.Away == 'CS Bakersfld'),'Away']= 'Cal St. Bakersfield'
Games.loc[(Games.Away == 'Ste F Austin'),'Away']= 'Stephen F. Austin'
Games.loc[(Games.Away == 'N Mex State'),'Away']= 'New Mexico St.'
Games.loc[(Games.Away == 'S Car State'),'Away']= 'South Carolina St.'
Games.loc[(Games.Away == 'SE Louisiana'),'Away']= 'Southeastern Louisiana'
Games.loc[(Games.Away == 'Northeastrn'),'Away']= 'Northeastern'
Games.loc[(Games.Away == 'Citadel'),'Away']= 'The Citadel'
Games.loc[(Games.Away == 'Utah State'),'Away']= 'Utah St.'
Games.loc[(Games.Away == 'St Johns'),'Away']= "St. John's"
Games.loc[(Games.Away == 'IPFW'),'Away']= 'Purdue Fort Wayne'
Games.loc[(Games.Away == 'Miss Val St'),'Away']= 'Mississippi Valley St.'
Games.loc[(Games.Away == 'San Fransco'),'Away']= 'San Francisco'
Games.loc[(Games.Away == 'LA Lafayette'),'Away']= 'Louisiana'
Games.loc[(Games.Away == 'VA Tech'),'Away']= 'Virginia Tech'
Games.loc[(Games.Away == 'N Iowa'),'Away']= 'Northern Iowa'
Games.loc[(Games.Away == 'IL-Chicago'),'Away']= 'Illinois Chicago'
Games.loc[(Games.Away == 'Grd Canyon'),'Away']= 'Grand Canyon'
Games.loc[(Games.Away == 'Cal St Nrdge'),'Away']= 'Cal St. Northridge'
Games.loc[(Games.Away == 'San Diego St'),'Away']= 'San Diego St.'
Games.loc[(Games.Away == 'W Kentucky'),'Away']= 'Western Kentucky'
Games.loc[(Games.Away == 'Lg Beach St'),'Away']= 'Long Beach St.'
Games.loc[(Games.Away == 'Wm & Mary'),'Away']= 'William & Mary'
Games.loc[(Games.Away == 'TX Southern'),'Away']= 'Texas Southern'
Games.loc[(Games.Away == 'Sam Hous St'),'Away']= 'Sam Houston St.'
Games.loc[(Games.Away == 'TX-Pan Am'),'Away']= 'UT Rio Grande Valley'
Games.loc[(Games.Away == 'Coppin State'),'Away']= 'Coppin St.'
Games.loc[(Games.Away == 'Miami (FL)'),'Away']= 'Miami FL'
Games.loc[(Games.Away == 'Maryland BC'),'Away']= 'UMBC'
Games.loc[(Games.Away == 'TX-Arlington'),'Away']= 'UT Arlington'
Games.loc[(Games.Away == 'Indiana St'),'Away']= 'Indiana St.'
Games.loc[(Games.Away == 'Fresno St'),'Away']= 'Fresno St.'
Games.loc[(Games.Away == 'E Kentucky'),'Away']= 'Eastern Kentucky'
Games.loc[(Games.Away == 'Oregon St'),'Away']= 'Oregon St.'
Games.loc[(Games.Away == 'McNeese St'),'Away']= 'McNeese St.'
Games.loc[(Games.Away == 'E Tenn St'),'Away']= 'East Tennessee St.'
Games.loc[(Games.Away == 'TX A&M-CC'),'Away']= 'Texas A&M Corpus Chris'
Games.loc[(Games.Away == 'E Michigan'),'Away']= 'Eastern Michigan'
Games.loc[(Games.Away == 'S Dakota St'),'Away']= 'South Dakota St.'
Games.loc[(Games.Away == 'Arizona St'),'Away']= 'Arizona St.'
Games.loc[(Games.Away == 'E Illinois'),'Away']= 'Eastern Illinois'
Games.loc[(Games.Away == 'W Virginia'),'Away']= 'West Virginia'
Games.loc[(Games.Away == 'Grambling St'),'Away']= 'Grambling St.'
Games.loc[(Games.Away == 'N Colorado'),'Away']= 'Northern Colorado'
Games.loc[(Games.Away == 'Youngs St'),'Away']= 'Youngstown St.'
Games.loc[(Games.Away == 'Loyola-MD'),'Away']= 'Loyola MD'
Games.loc[(Games.Away == 'Wright State'),'Away']= 'Wright St.'
Games.loc[(Games.Away == 'Mass Lowell'),'Away']= 'UMass Lowell'
Games.loc[(Games.Away == 'Sac State'),'Away']= 'Sacramento St.'
Games.loc[(Games.Away == 'San Jose St'),'Away']= 'San Jose St.'
Games.loc[(Games.Away == 'St Peters'),'Away']= "Saint Peter's"
Games.loc[(Games.Away == 'Dixie State'),'Away']= 'Dixie St.'
Games.loc[(Games.Away == 'Morgan St'),'Away']= 'Morgan St.'
Games.loc[(Games.Away == 'Fla Gulf Cst'),'Away']= 'Florida Gulf Coast'
Games.loc[(Games.Away == 'N Florida'),'Away']= 'North Florida'
Games.loc[(Games.Away == 'St. Thomas (MN)'),'Away']= 'St. Thomas'
Games.loc[(Games.Away == 'Fla Atlantic'),'Away']= 'Florida Atlantic'
Games.loc[(Games.Away == 'Arkansas St'),'Away']= 'Arkansas St.'
Games.loc[(Games.Away == 'NC A&T'),'Away']= 'North Carolina A&T'
Games.loc[(Games.Away == 'Alcorn State'),'Away']= 'Alcorn St.'
Games.loc[(Games.Away == 'Utah Val St'),'Away']= 'Utah Valley'
Games.loc[(Games.Away == 'App State'),'Away']= 'Appalachian St.'
Games.loc[(Games.Away == 'Beth-Cook'),'Away']= 'Bethune Cookman'
Games.loc[(Games.Away == 'Iowa State'),'Away']= 'Iowa St.'
Games.loc[(Games.Away == 'Michigan St'),'Away']= 'Michigan St.'
Games.loc[(Games.Away == 'WI-Grn Bay'),'Away']= 'Green Bay'
Games.loc[(Games.Away == 'Houston Bap'),'Away']= 'Houston Baptist'
Games.loc[(Games.Away == 'N Hampshire'),'Away']= 'New Hampshire'
Games.loc[(Games.Away == 'S Florida'),'Away']= 'South Florida'
Games.loc[(Games.Away == 'Murray St'),'Away']= 'Murray St.'
Games.loc[(Games.Away == 'Central Conn'),'Away']= 'Central Connecticut'
Games.loc[(Games.Away == 'Morehead St'),'Away']= 'Morehead St.'
Games.loc[(Games.Away == 'GA Tech'),'Away']= 'Georgia Tech'
Games.loc[(Games.Away == 'TX-San Ant'),'Away']= 'UTSA'
Games.loc[(Games.Away == 'N Alabama'),'Away']= 'North Alabama'
Games.loc[(Games.Away == 'St Josephs'),'Away']= "Saint Joseph's"
Games.loc[(Games.Away == 'SC Upstate'),'Away']= 'USC Upstate'
Games.loc[(Games.Away == 'Portland St'),'Away']= 'Portland St.'
Games.loc[(Games.Away == 'Kansas St'),'Away']= 'Kansas St.'
Games.loc[(Games.Away == 'Delaware St'),'Away']= 'Delaware St.'
Games.loc[(Games.Away == 'Montana St'),'Away']= 'Montana St.'
Games.loc[(Games.Away == 'Geo Wshgtn'),'Away']= 'George Washington'
Games.loc[(Games.Away == 'Miami (OH)'),'Away']= 'Miami OH'
Games.loc[(Games.Away == 'Central FL'),'Away']= 'UCF'
Games.loc[(Games.Away == 'Tarleton State'),'Away']= 'Tarleton St.'
Games.loc[(Games.Away == 'WI-Milwkee'),'Away']= 'Milwaukee'
Games.loc[(Games.Away == 'GA Southern'),'Away']= 'Georgia Southern'
Games.loc[(Games.Away == 'Texas State'),'Away']= 'Texas St.'
Games.loc[(Games.Away == 'St Bonavent'),'Away']= 'St. Bonaventure'
Games.loc[(Games.Away == 'Boston Col'),'Away']= 'Boston College'
Games.loc[(Games.Away == 'Col Charlestn'),'Away']= 'Charleston'
Games.loc[(Games.Away == 'U Mass'),'Away']= 'Massachusetts'
Games.loc[(Games.Away == 'NC-Asheville'),'Away']= 'UNC Asheville'
Games.loc[(Games.Away == 'Norfolk St'),'Away']= 'Norfolk St.'
Games.loc[(Games.Away == 'Colorado St'),'Away']= 'Colorado St.'
Games.loc[(Games.Away == 'Sacred Hrt'),'Away']= 'Sacred Heart'
Games.loc[(Games.Away == 'Missouri St'),'Away']= 'Missouri St.'
Games.loc[(Games.Away == 'Coastal Car'),'Away']= 'Coastal Carolina'
Games.loc[(Games.Away == 'NC State'),'Away']= 'N.C. State'
Games.loc[(Games.Away == 'Charl South'),'Away']= 'Charleston Southern'
Games.loc[(Games.Away == 'Chicago St'),'Away']= 'Chicago St.'
Games.loc[(Games.Away == 'N Illinois'),'Away']= 'Northern Illinois'
Games.loc[(Games.Away == 'Illinois St'),'Away']= 'Illinois St.'
Games.loc[(Games.Away == 'Jksnville St'),'Away']= 'Jacksonville St.'
Games.loc[(Games.Away == 'Boise State'),'Away']= 'Boise St.'
Games.loc[(Games.Away == 'Ohio State'),'Away']= 'Ohio St.'
Games.loc[(Games.Away == 'Florida Intl'),'Away']= 'FIU'
Games.loc[(Games.Away == 'W Michigan'),'Away']= 'Western Michigan'
Games.loc[(Games.Away == 'Rob Morris'),'Away']= 'Robert Morris'
Games.loc[(Games.Away == 'Ark Pine Bl'),'Away']= 'Arkansas Pine Bluff'
Games.loc[(Games.Away == 'Ball State'),'Away']= 'Ball St.'
Games.loc[(Games.Away == 'LA Monroe'),'Away']= 'Louisiana Monroe'
Games.loc[(Games.Away == 'S Methodist'),'Away']= 'Southern Methodist'
Games.loc[(Games.Away == 'Cleveland St'),'Away']= 'Cleveland St.'
Games.loc[(Games.Away == 'Kennesaw St'),'Away']= 'Kennesaw St.'
Games.loc[(Games.Away == 'James Mad'),'Away']= 'James Madison'
Games.loc[(Games.Away == 'Oklahoma St'),'Away']= 'Oklahoma St.'
Games.loc[(Games.Away == 'N Kentucky'),'Away']= 'Northern Kentucky'
Games.loc[(Games.Away == 'St Fran (PA)'),'Away']= 'St. Francis PA'
Games.loc[(Games.Away == 'S Carolina'),'Away']= 'South Carolina'
Games.loc[(Games.Away == 'Southern Methodist'),'Away']= 'SMU'
Games.loc[(Games.Away == 'Penn State'),'Away']= 'Penn St.'
Games.loc[(Games.Away == 'Florida St'),'Away']= 'Florida St.'
Games.loc[(Games.Away == 'N Dakota St'),'Away']= 'North Dakota St.'
Games.loc[(Games.Away == 'Weber State'),'Away']= 'Weber St.'
Games.loc[(Games.Away == 'VA Military'),'Away']= 'VMI'
Games.loc[(Games.Away == 'Nicholls St'),'Away']= 'Nicholls St.'
Games.loc[(Games.Away == 'SE Missouri'),'Away']= 'Southeast Missouri St.'
Games.loc[(Games.Away == 'Geo Mason'),'Away']= 'George Mason'
Games.loc[(Games.Away == 'Idaho State'),'Away']= 'Idaho St.'
Games.loc[(Games.Away == 'Loyola Mymt'),'Away']= 'Loyola Marymount'
Games.loc[(Games.Away == 'UCSB'),'Away']= 'UC Santa Barbara'
Games.loc[(Games.Away == 'S Mississippi'),'Away']= 'Southern Miss'
Games.loc[(Games.Away == 'S Utah'),'Away']= 'Southern Utah'
Games.loc[(Games.Away == 'Mt St Marys'),'Away']= "Mount St. Mary's"
Games.loc[(Games.Away == 'F Dickinson'),'Away']= 'Fairleigh Dickinson'
Games.loc[(Games.Away == 'W Carolina'),'Away']= 'Western Carolina'
Games.loc[(Games.Away == 'Jackson St'),'Away']= 'Jackson St.'
Games.loc[(Games.Away == 'Wichita St'),'Away']= 'Wichita St.'
Games.loc[(Games.Away == 'E Washingtn'),'Away']= 'Eastern Washington'
Games.loc[(Games.Away == 'NC Central'),'Away']= 'North Carolina Central'
Games.loc[(Games.Away == 'Georgia St'),'Away']= 'Georgia St.'
Games.loc[(Games.Away == 'Kent State'),'Away']= 'Kent St.'
Games.loc[(Games.Away == 'Prairie View'),'Away']= 'Prairie View A&M'
Games.loc[(Games.Away == 'AR Lit Rock'),'Away']= 'Little Rock'
Games.loc[(Games.Away == 'Incar Word'),'Away']= 'Incarnate Word'
Games.loc[(Games.Away == 'NC-Grnsboro'),'Away']= 'UNC Greensboro'
Games.loc[(Games.Away == 'Bowling Grn'),'Away']= 'Bowling Green'
Games.loc[(Games.Away == 'W Illinois'),'Away']= 'Western Illinois'
Games.loc[(Games.Away == 'St Marys'),'Away']= "Saint Mary's"
Games.loc[(Games.Away == 'TN Martin'),'Away']= 'Tennessee Martin'
Games.loc[(Games.Away == 'Miss State'),'Away']= 'Mississippi St.'
Games.loc[(Games.Away == 'Maryland ES'),'Away']= 'Maryland Eastern Shore'
Games.loc[(Games.Away == 'Gard-Webb'),'Away']= 'Gardner Webb'
Games.loc[(Games.Away == 'Central Ark'),'Away']= 'Central Arkansas'
Games.loc[(Games.Away == 'TN State'),'Away']= 'Tennessee St.'
Games.loc[(Games.Away == 'S Illinois'),'Away']= 'Southern Illinois'
Games.loc[(Games.Away == 'Alab A&M'),'Away']= 'Alabama A&M'
Games.loc[(Games.Away == 'TX Christian'),'Away']= 'TCU'
Games.loc[(Games.Away == 'St Fran (NY)'),'Away']= 'St. Francis NY'
Games.loc[(Games.Away == 'Central Mich'),'Away']= 'Central Michigan'
Games.loc[(Games.Away == 'Boston U'),'Away']= 'Boston University'
Games.loc[(Games.Away == 'N Carolina'),'Away']= 'North Carolina'
Games.loc[(Games.Away == 'Loyola-Chi'),'Away']= 'Loyola Chicago'
Games.loc[(Games.Away == 'Alabama St'),'Away']= 'Alabama St.'
Games.loc[(Games.Away == 'CS Fullerton'),'Away']= 'Cal St. Fullerton'

# %%
Games.loc[(Games.Home == 'Wash State'),'Home']= 'Washington St.'
Games.loc[(Games.Home == 'Abl Christian'),'Home']= 'Abilene Christian'
Games.loc[(Games.Home == 'N Arizona'),'Home']= 'Northern Arizona'
Games.loc[(Games.Home == 'U Penn'),'Home']= 'Penn'
Games.loc[(Games.Home == 'TX El Paso'),'Home']= 'UTEP'
Games.loc[(Games.Home == 'SIU Edward'),'Home']= 'SIU Edwardsville'
Games.loc[(Games.Home == 'TN Tech'),'Home']= 'Tennessee Tech'
Games.loc[(Games.Home == 'Middle Tenn'),'Home']= 'Middle Tennessee'
Games.loc[(Games.Home == 'Neb Omaha'),'Home']= 'Nebraska Omaha'
Games.loc[(Games.Home == 'LA Tech'),'Home']= 'Louisiana Tech'
Games.loc[(Games.Home == 'S Alabama'),'Home']= 'South Alabama'
Games.loc[(Games.Home == 'NC-Wilmgton'),'Home']= 'UNC Wilmington'
Games.loc[(Games.Home == 'NW State'),'Home']= 'Northwestern St.'
Games.loc[(Games.Home == 'E Carolina'),'Home']= 'East Carolina'
Games.loc[(Games.Home == 'Detroit'),'Home']= 'Detroit Mercy'
Games.loc[(Games.Home == 'CS Bakersfld'),'Home']= 'Cal St. Bakersfield'
Games.loc[(Games.Home == 'Ste F Austin'),'Home']= 'Stephen F. Austin'
Games.loc[(Games.Home == 'N Mex State'),'Home']= 'New Mexico St.'
Games.loc[(Games.Home == 'S Car State'),'Home']= 'South Carolina St.'
Games.loc[(Games.Home == 'SE Louisiana'),'Home']= 'Southeastern Louisiana'
Games.loc[(Games.Home == 'Northeastrn'),'Home']= 'Northeastern'
Games.loc[(Games.Home == 'Citadel'),'Home']= 'The Citadel'
Games.loc[(Games.Home == 'Utah State'),'Home']= 'Utah St.'
Games.loc[(Games.Home == 'St Johns'),'Home']= "St. John's"
Games.loc[(Games.Home == 'IPFW'),'Home']= 'Purdue Fort Wayne'
Games.loc[(Games.Home == 'Miss Val St'),'Home']= 'Mississippi Valley St.'
Games.loc[(Games.Home == 'San Fransco'),'Home']= 'San Francisco'
Games.loc[(Games.Home == 'LA Lafayette'),'Home']= 'Louisiana'
Games.loc[(Games.Home == 'VA Tech'),'Home']= 'Virginia Tech'
Games.loc[(Games.Home == 'N Iowa'),'Home']= 'Northern Iowa'
Games.loc[(Games.Home == 'IL-Chicago'),'Home']= 'Illinois Chicago'
Games.loc[(Games.Home == 'Grd Canyon'),'Home']= 'Grand Canyon'
Games.loc[(Games.Home == 'Cal St Nrdge'),'Home']= 'Cal St. Northridge'
Games.loc[(Games.Home == 'San Diego St'),'Home']= 'San Diego St.'
Games.loc[(Games.Home == 'W Kentucky'),'Home']= 'Western Kentucky'
Games.loc[(Games.Home == 'Lg Beach St'),'Home']= 'Long Beach St.'
Games.loc[(Games.Home == 'Wm & Mary'),'Home']= 'William & Mary'
Games.loc[(Games.Home == 'TX Southern'),'Home']= 'Texas Southern'
Games.loc[(Games.Home == 'Sam Hous St'),'Home']= 'Sam Houston St.'
Games.loc[(Games.Home == 'TX-Pan Am'),'Home']= 'UT Rio Grande Valley'
Games.loc[(Games.Home == 'Coppin State'),'Home']= 'Coppin St.'
Games.loc[(Games.Home == 'Miami (FL)'),'Home']= 'Miami FL'
Games.loc[(Games.Home == 'Maryland BC'),'Home']= 'UMBC'
Games.loc[(Games.Home == 'TX-Arlington'),'Home']= 'UT Arlington'
Games.loc[(Games.Home == 'Indiana St'),'Home']= 'Indiana St.'
Games.loc[(Games.Home == 'Fresno St'),'Home']= 'Fresno St.'
Games.loc[(Games.Home == 'E Kentucky'),'Home']= 'Eastern Kentucky'
Games.loc[(Games.Home == 'Oregon St'),'Home']= 'Oregon St.'
Games.loc[(Games.Home == 'McNeese St'),'Home']= 'McNeese St.'
Games.loc[(Games.Home == 'E Tenn St'),'Home']= 'East Tennessee St.'
Games.loc[(Games.Home == 'TX A&M-CC'),'Home']= 'Texas A&M Corpus Chris'
Games.loc[(Games.Home == 'E Michigan'),'Home']= 'Eastern Michigan'
Games.loc[(Games.Home == 'S Dakota St'),'Home']= 'South Dakota St.'
Games.loc[(Games.Home == 'Arizona St'),'Home']= 'Arizona St.'
Games.loc[(Games.Home == 'E Illinois'),'Home']= 'Eastern Illinois'
Games.loc[(Games.Home == 'W Virginia'),'Home']= 'West Virginia'
Games.loc[(Games.Home == 'Grambling St'),'Home']= 'Grambling St.'
Games.loc[(Games.Home == 'N Colorado'),'Home']= 'Northern Colorado'
Games.loc[(Games.Home == 'Youngs St'),'Home']= 'Youngstown St.'
Games.loc[(Games.Home == 'Loyola-MD'),'Home']= 'Loyola MD'
Games.loc[(Games.Home == 'Wright State'),'Home']= 'Wright St.'
Games.loc[(Games.Home == 'Mass Lowell'),'Home']= 'UMass Lowell'
Games.loc[(Games.Home == 'Sac State'),'Home']= 'Sacramento St.'
Games.loc[(Games.Home == 'San Jose St'),'Home']= 'San Jose St.'
Games.loc[(Games.Home == 'St Peters'),'Home']= "Saint Peter's"
Games.loc[(Games.Home == 'Dixie State'),'Home']= 'Dixie St.'
Games.loc[(Games.Home == 'Morgan St'),'Home']= 'Morgan St.'
Games.loc[(Games.Home == 'Fla Gulf Cst'),'Home']= 'Florida Gulf Coast'
Games.loc[(Games.Home == 'N Florida'),'Home']= 'North Florida'
Games.loc[(Games.Home == 'St. Thomas (MN)'),'Home']= 'St. Thomas'
Games.loc[(Games.Home == 'Fla Atlantic'),'Home']= 'Florida Atlantic'
Games.loc[(Games.Home == 'Arkansas St'),'Home']= 'Arkansas St.'
Games.loc[(Games.Home == 'NC A&T'),'Home']= 'North Carolina A&T'
Games.loc[(Games.Home == 'Alcorn State'),'Home']= 'Alcorn St.'
Games.loc[(Games.Home == 'Utah Val St'),'Home']= 'Utah Valley'
Games.loc[(Games.Home == 'App State'),'Home']= 'Appalachian St.'
Games.loc[(Games.Home == 'Beth-Cook'),'Home']= 'Bethune Cookman'
Games.loc[(Games.Home == 'Iowa State'),'Home']= 'Iowa St.'
Games.loc[(Games.Home == 'Michigan St'),'Home']= 'Michigan St.'
Games.loc[(Games.Home == 'WI-Grn Bay'),'Home']= 'Green Bay'
Games.loc[(Games.Home == 'Houston Bap'),'Home']= 'Houston Baptist'
Games.loc[(Games.Home == 'N Hampshire'),'Home']= 'New Hampshire'
Games.loc[(Games.Home == 'S Florida'),'Home']= 'South Florida'
Games.loc[(Games.Home == 'Murray St'),'Home']= 'Murray St.'
Games.loc[(Games.Home == 'Central Conn'),'Home']= 'Central Connecticut'
Games.loc[(Games.Home == 'Morehead St'),'Home']= 'Morehead St.'
Games.loc[(Games.Home == 'GA Tech'),'Home']= 'Georgia Tech'
Games.loc[(Games.Home == 'TX-San Ant'),'Home']= 'UTSA'
Games.loc[(Games.Home == 'N Alabama'),'Home']= 'North Alabama'
Games.loc[(Games.Home == 'St Josephs'),'Home']= "Saint Joseph's"
Games.loc[(Games.Home == 'SC Upstate'),'Home']= 'USC Upstate'
Games.loc[(Games.Home == 'Portland St'),'Home']= 'Portland St.'
Games.loc[(Games.Home == 'Kansas St'),'Home']= 'Kansas St.'
Games.loc[(Games.Home == 'Delaware St'),'Home']= 'Delaware St.'
Games.loc[(Games.Home == 'Montana St'),'Home']= 'Montana St.'
Games.loc[(Games.Home == 'Geo Wshgtn'),'Home']= 'George Washington'
Games.loc[(Games.Home == 'Miami (OH)'),'Home']= 'Miami OH'
Games.loc[(Games.Home == 'Central FL'),'Home']= 'UCF'
Games.loc[(Games.Home == 'Tarleton State'),'Home']= 'Tarleton St.'
Games.loc[(Games.Home == 'WI-Milwkee'),'Home']= 'Milwaukee'
Games.loc[(Games.Home == 'GA Southern'),'Home']= 'Georgia Southern'
Games.loc[(Games.Home == 'Texas State'),'Home']= 'Texas St.'
Games.loc[(Games.Home == 'St Bonavent'),'Home']= 'St. Bonaventure'
Games.loc[(Games.Home == 'Boston Col'),'Home']= 'Boston College'
Games.loc[(Games.Home == 'Col Charlestn'),'Home']= 'Charleston'
Games.loc[(Games.Home == 'U Mass'),'Home']= 'Massachusetts'
Games.loc[(Games.Home == 'NC-Asheville'),'Home']= 'UNC Asheville'
Games.loc[(Games.Home == 'Norfolk St'),'Home']= 'Norfolk St.'
Games.loc[(Games.Home == 'Colorado St'),'Home']= 'Colorado St.'
Games.loc[(Games.Home == 'Sacred Hrt'),'Home']= 'Sacred Heart'
Games.loc[(Games.Home == 'Missouri St'),'Home']= 'Missouri St.'
Games.loc[(Games.Home == 'Coastal Car'),'Home']= 'Coastal Carolina'
Games.loc[(Games.Home == 'NC State'),'Home']= 'N.C. State'
Games.loc[(Games.Home == 'Charl South'),'Home']= 'Charleston Southern'
Games.loc[(Games.Home == 'Chicago St'),'Home']= 'Chicago St.'
Games.loc[(Games.Home == 'N Illinois'),'Home']= 'Northern Illinois'
Games.loc[(Games.Home == 'Illinois St'),'Home']= 'Illinois St.'
Games.loc[(Games.Home == 'Jksnville St'),'Home']= 'Jacksonville St.'
Games.loc[(Games.Home == 'Boise State'),'Home']= 'Boise St.'
Games.loc[(Games.Home == 'Ohio State'),'Home']= 'Ohio St.'
Games.loc[(Games.Home == 'Florida Intl'),'Home']= 'FIU'
Games.loc[(Games.Home == 'W Michigan'),'Home']= 'Western Michigan'
Games.loc[(Games.Home == 'Rob Morris'),'Home']= 'Robert Morris'
Games.loc[(Games.Home == 'Ark Pine Bl'),'Home']= 'Arkansas Pine Bluff'
Games.loc[(Games.Home == 'Ball State'),'Home']= 'Ball St.'
Games.loc[(Games.Home == 'LA Monroe'),'Home']= 'Louisiana Monroe'
Games.loc[(Games.Home == 'S Methodist'),'Home']= 'Southern Methodist'
Games.loc[(Games.Home == 'Cleveland St'),'Home']= 'Cleveland St.'
Games.loc[(Games.Home == 'Kennesaw St'),'Home']= 'Kennesaw St.'
Games.loc[(Games.Home == 'James Mad'),'Home']= 'James Madison'
Games.loc[(Games.Home == 'Oklahoma St'),'Home']= 'Oklahoma St.'
Games.loc[(Games.Home == 'N Kentucky'),'Home']= 'Northern Kentucky'
Games.loc[(Games.Home == 'St Fran (PA)'),'Home']= 'St. Francis PA'
Games.loc[(Games.Home == 'S Carolina'),'Home']= 'South Carolina'
Games.loc[(Games.Home == 'Southern Methodist'),'Home']= 'SMU'
Games.loc[(Games.Home == 'Penn State'),'Home']= 'Penn St.'
Games.loc[(Games.Home == 'Florida St'),'Home']= 'Florida St.'
Games.loc[(Games.Home == 'N Dakota St'),'Home']= 'North Dakota St.'
Games.loc[(Games.Home == 'Weber State'),'Home']= 'Weber St.'
Games.loc[(Games.Home == 'VA Military'),'Home']= 'VMI'
Games.loc[(Games.Home == 'Nicholls St'),'Home']= 'Nicholls St.'
Games.loc[(Games.Home == 'SE Missouri'),'Home']= 'Southeast Missouri St.'
Games.loc[(Games.Home == 'Geo Mason'),'Home']= 'George Mason'
Games.loc[(Games.Home == 'Idaho State'),'Home']= 'Idaho St.'
Games.loc[(Games.Home == 'Loyola Mymt'),'Home']= 'Loyola Marymount'
Games.loc[(Games.Home == 'UCSB'),'Home']= 'UC Santa Barbara'
Games.loc[(Games.Home == 'S Mississippi'),'Home']= 'Southern Miss'
Games.loc[(Games.Home == 'S Utah'),'Home']= 'Southern Utah'
Games.loc[(Games.Home == 'Mt St Marys'),'Home']= "Mount St. Mary's"
Games.loc[(Games.Home == 'F Dickinson'),'Home']= 'Fairleigh Dickinson'
Games.loc[(Games.Home == 'W Carolina'),'Home']= 'Western Carolina'
Games.loc[(Games.Home == 'Jackson St'),'Home']= 'Jackson St.'
Games.loc[(Games.Home == 'Wichita St'),'Home']= 'Wichita St.'
Games.loc[(Games.Home == 'E Washingtn'),'Home']= 'Eastern Washington'
Games.loc[(Games.Home == 'NC Central'),'Home']= 'North Carolina Central'
Games.loc[(Games.Home == 'Georgia St'),'Home']= 'Georgia St.'
Games.loc[(Games.Home == 'Kent State'),'Home']= 'Kent St.'
Games.loc[(Games.Home == 'Prairie View'),'Home']= 'Prairie View A&M'
Games.loc[(Games.Home == 'AR Lit Rock'),'Home']= 'Little Rock'
Games.loc[(Games.Home == 'Incar Word'),'Home']= 'Incarnate Word'
Games.loc[(Games.Home == 'NC-Grnsboro'),'Home']= 'UNC Greensboro'
Games.loc[(Games.Home == 'Bowling Grn'),'Home']= 'Bowling Green'
Games.loc[(Games.Home == 'W Illinois'),'Home']= 'Western Illinois'
Games.loc[(Games.Home == 'St Marys'),'Home']= "Saint Mary's"
Games.loc[(Games.Home == 'TN Martin'),'Home']= 'Tennessee Martin'
Games.loc[(Games.Home == 'Miss State'),'Home']= 'Mississippi St.'
Games.loc[(Games.Home == 'Maryland ES'),'Home']= 'Maryland Eastern Shore'
Games.loc[(Games.Home == 'Gard-Webb'),'Home']= 'Gardner Webb'
Games.loc[(Games.Home == 'Central Ark'),'Home']= 'Central Arkansas'
Games.loc[(Games.Home == 'TN State'),'Home']= 'Tennessee St.'
Games.loc[(Games.Home == 'S Illinois'),'Home']= 'Southern Illinois'
Games.loc[(Games.Home == 'Alab A&M'),'Home']= 'Alabama A&M'
Games.loc[(Games.Home == 'TX Christian'),'Home']= 'TCU'
Games.loc[(Games.Home == 'St Fran (NY)'),'Home']= 'St. Francis NY'
Games.loc[(Games.Home == 'Central Mich'),'Home']= 'Central Michigan'
Games.loc[(Games.Home == 'Boston U'),'Home']= 'Boston University'
Games.loc[(Games.Home == 'N Carolina'),'Home']= 'North Carolina'
Games.loc[(Games.Home == 'Loyola-Chi'),'Home']= 'Loyola Chicago'
Games.loc[(Games.Home == 'Alabama St'),'Home']= 'Alabama St.'
Games.loc[(Games.Home == 'CS Fullerton'),'Home']= 'Cal St. Fullerton'

# %%
Final.loc[(Final.Team == 'Wash State'),'Team']= 'Washington St.'
Final.loc[(Final.Team == 'Abl Christian'),'Team']= 'Abilene Christian'
Final.loc[(Final.Team == 'N Arizona'),'Team']= 'Northern Arizona'
Final.loc[(Final.Team == 'U Penn'),'Team']= 'Penn'
Final.loc[(Final.Team == 'TX El Paso'),'Team']= 'UTEP'
Final.loc[(Final.Team == 'SIU Edward'),'Team']= 'SIU Edwardsville'
Final.loc[(Final.Team == 'TN Tech'),'Team']= 'Tennessee Tech'
Final.loc[(Final.Team == 'Middle Tenn'),'Team']= 'Middle Tennessee'
Final.loc[(Final.Team == 'Neb Omaha'),'Team']= 'Nebraska Omaha'
Final.loc[(Final.Team == 'LA Tech'),'Team']= 'Louisiana Tech'
Final.loc[(Final.Team == 'S Alabama'),'Team']= 'South Alabama'
Final.loc[(Final.Team == 'NC-Wilmgton'),'Team']= 'UNC Wilmington'
Final.loc[(Final.Team == 'NW State'),'Team']= 'Northwestern St.'
Final.loc[(Final.Team == 'E Carolina'),'Team']= 'East Carolina'
Final.loc[(Final.Team == 'Detroit'),'Team']= 'Detroit Mercy'
Final.loc[(Final.Team == 'CS Bakersfld'),'Team']= 'Cal St. Bakersfield'
Final.loc[(Final.Team == 'Ste F Austin'),'Team']= 'Stephen F. Austin'
Final.loc[(Final.Team == 'N Mex State'),'Team']= 'New Mexico St.'
Final.loc[(Final.Team == 'S Car State'),'Team']= 'South Carolina St.'
Final.loc[(Final.Team == 'SE Louisiana'),'Team']= 'Southeastern Louisiana'
Final.loc[(Final.Team == 'Northeastrn'),'Team']= 'Northeastern'
Final.loc[(Final.Team == 'Citadel'),'Team']= 'The Citadel'
Final.loc[(Final.Team == 'Utah State'),'Team']= 'Utah St.'
Final.loc[(Final.Team == 'St Johns'),'Team']= "St. John's"
Final.loc[(Final.Team == 'IPFW'),'Team']= 'Purdue Fort Wayne'
Final.loc[(Final.Team == 'Miss Val St'),'Team']= 'Mississippi Valley St.'
Final.loc[(Final.Team == 'San Fransco'),'Team']= 'San Francisco'
Final.loc[(Final.Team == 'LA Lafayette'),'Team']= 'Louisiana'
Final.loc[(Final.Team == 'VA Tech'),'Team']= 'Virginia Tech'
Final.loc[(Final.Team == 'N Iowa'),'Team']= 'Northern Iowa'
Final.loc[(Final.Team == 'IL-Chicago'),'Team']= 'Illinois Chicago'
Final.loc[(Final.Team == 'Grd Canyon'),'Team']= 'Grand Canyon'
Final.loc[(Final.Team == 'Cal St Nrdge'),'Team']= 'Cal St. Northridge'
Final.loc[(Final.Team == 'San Diego St'),'Team']= 'San Diego St.'
Final.loc[(Final.Team == 'W Kentucky'),'Team']= 'Western Kentucky'
Final.loc[(Final.Team == 'Lg Beach St'),'Team']= 'Long Beach St.'
Final.loc[(Final.Team == 'Wm & Mary'),'Team']= 'William & Mary'
Final.loc[(Final.Team == 'TX Southern'),'Team']= 'Texas Southern'
Final.loc[(Final.Team == 'Sam Hous St'),'Team']= 'Sam Houston St.'
Final.loc[(Final.Team == 'TX-Pan Am'),'Team']= 'UT Rio Grande Valley'
Final.loc[(Final.Team == 'Coppin State'),'Team']= 'Coppin St.'
Final.loc[(Final.Team == 'Miami (FL)'),'Team']= 'Miami FL'
Final.loc[(Final.Team == 'Maryland BC'),'Team']= 'UMBC'
Final.loc[(Final.Team == 'TX-Arlington'),'Team']= 'UT Arlington'
Final.loc[(Final.Team == 'Indiana St'),'Team']= 'Indiana St.'
Final.loc[(Final.Team == 'Fresno St'),'Team']= 'Fresno St.'
Final.loc[(Final.Team == 'E Kentucky'),'Team']= 'Eastern Kentucky'
Final.loc[(Final.Team == 'Oregon St'),'Team']= 'Oregon St.'
Final.loc[(Final.Team == 'McNeese St'),'Team']= 'McNeese St.'
Final.loc[(Final.Team == 'E Tenn St'),'Team']= 'East Tennessee St.'
Final.loc[(Final.Team == 'TX A&M-CC'),'Team']= 'Texas A&M Corpus Chris'
Final.loc[(Final.Team == 'E Michigan'),'Team']= 'Eastern Michigan'
Final.loc[(Final.Team == 'S Dakota St'),'Team']= 'South Dakota St.'
Final.loc[(Final.Team == 'Arizona St'),'Team']= 'Arizona St.'
Final.loc[(Final.Team == 'E Illinois'),'Team']= 'Eastern Illinois'
Final.loc[(Final.Team == 'W Virginia'),'Team']= 'West Virginia'
Final.loc[(Final.Team == 'Grambling St'),'Team']= 'Grambling St.'
Final.loc[(Final.Team == 'N Colorado'),'Team']= 'Northern Colorado'
Final.loc[(Final.Team == 'Youngs St'),'Team']= 'Youngstown St.'
Final.loc[(Final.Team == 'Loyola-MD'),'Team']= 'Loyola MD'
Final.loc[(Final.Team == 'Wright State'),'Team']= 'Wright St.'
Final.loc[(Final.Team == 'Mass Lowell'),'Team']= 'UMass Lowell'
Final.loc[(Final.Team == 'Sac State'),'Team']= 'Sacramento St.'
Final.loc[(Final.Team == 'San Jose St'),'Team']= 'San Jose St.'
Final.loc[(Final.Team == 'St Peters'),'Team']= "Saint Peter's"
Final.loc[(Final.Team == 'Dixie State'),'Team']= 'Dixie St.'
Final.loc[(Final.Team == 'Morgan St'),'Team']= 'Morgan St.'
Final.loc[(Final.Team == 'Fla Gulf Cst'),'Team']= 'Florida Gulf Coast'
Final.loc[(Final.Team == 'N Florida'),'Team']= 'North Florida'
Final.loc[(Final.Team == 'St. Thomas (MN)'),'Team']= 'St. Thomas'
Final.loc[(Final.Team == 'Fla Atlantic'),'Team']= 'Florida Atlantic'
Final.loc[(Final.Team == 'Arkansas St'),'Team']= 'Arkansas St.'
Final.loc[(Final.Team == 'NC A&T'),'Team']= 'North Carolina A&T'
Final.loc[(Final.Team == 'Alcorn State'),'Team']= 'Alcorn St.'
Final.loc[(Final.Team == 'Utah Val St'),'Team']= 'Utah Valley'
Final.loc[(Final.Team == 'App State'),'Team']= 'Appalachian St.'
Final.loc[(Final.Team == 'Beth-Cook'),'Team']= 'Bethune Cookman'
Final.loc[(Final.Team == 'Iowa State'),'Team']= 'Iowa St.'
Final.loc[(Final.Team == 'Michigan St'),'Team']= 'Michigan St.'
Final.loc[(Final.Team == 'WI-Grn Bay'),'Team']= 'Green Bay'
Final.loc[(Final.Team == 'Houston Bap'),'Team']= 'Houston Baptist'
Final.loc[(Final.Team == 'N Hampshire'),'Team']= 'New Hampshire'
Final.loc[(Final.Team == 'S Florida'),'Team']= 'South Florida'
Final.loc[(Final.Team == 'Murray St'),'Team']= 'Murray St.'
Final.loc[(Final.Team == 'Central Conn'),'Team']= 'Central Connecticut'
Final.loc[(Final.Team == 'Morehead St'),'Team']= 'Morehead St.'
Final.loc[(Final.Team == 'GA Tech'),'Team']= 'Georgia Tech'
Final.loc[(Final.Team == 'TX-San Ant'),'Team']= 'UTSA'
Final.loc[(Final.Team == 'N Alabama'),'Team']= 'North Alabama'
Final.loc[(Final.Team == 'St Josephs'),'Team']= "Saint Joseph's"
Final.loc[(Final.Team == 'SC Upstate'),'Team']= 'USC Upstate'
Final.loc[(Final.Team == 'Portland St'),'Team']= 'Portland St.'
Final.loc[(Final.Team == 'Kansas St'),'Team']= 'Kansas St.'
Final.loc[(Final.Team == 'Delaware St'),'Team']= 'Delaware St.'
Final.loc[(Final.Team == 'Montana St'),'Team']= 'Montana St.'
Final.loc[(Final.Team == 'Geo Wshgtn'),'Team']= 'George Washington'
Final.loc[(Final.Team == 'Miami (OH)'),'Team']= 'Miami OH'
Final.loc[(Final.Team == 'Central FL'),'Team']= 'UCF'
Final.loc[(Final.Team == 'Tarleton State'),'Team']= 'Tarleton St.'
Final.loc[(Final.Team == 'WI-Milwkee'),'Team']= 'Milwaukee'
Final.loc[(Final.Team == 'GA Southern'),'Team']= 'Georgia Southern'
Final.loc[(Final.Team == 'Texas State'),'Team']= 'Texas St.'
Final.loc[(Final.Team == 'St Bonavent'),'Team']= 'St. Bonaventure'
Final.loc[(Final.Team == 'Boston Col'),'Team']= 'Boston College'
Final.loc[(Final.Team == 'Col Charlestn'),'Team']= 'Charleston'
Final.loc[(Final.Team == 'U Mass'),'Team']= 'Massachusetts'
Final.loc[(Final.Team == 'NC-Asheville'),'Team']= 'UNC Asheville'
Final.loc[(Final.Team == 'Norfolk St'),'Team']= 'Norfolk St.'
Final.loc[(Final.Team == 'Colorado St'),'Team']= 'Colorado St.'
Final.loc[(Final.Team == 'Sacred Hrt'),'Team']= 'Sacred Heart'
Final.loc[(Final.Team == 'Missouri St'),'Team']= 'Missouri St.'
Final.loc[(Final.Team == 'Coastal Car'),'Team']= 'Coastal Carolina'
Final.loc[(Final.Team == 'NC State'),'Team']= 'N.C. State'
Final.loc[(Final.Team == 'Charl South'),'Team']= 'Charleston Southern'
Final.loc[(Final.Team == 'Chicago St'),'Team']= 'Chicago St.'
Final.loc[(Final.Team == 'N Illinois'),'Team']= 'Northern Illinois'
Final.loc[(Final.Team == 'Illinois St'),'Team']= 'Illinois St.'
Final.loc[(Final.Team == 'Jksnville St'),'Team']= 'Jacksonville St.'
Final.loc[(Final.Team == 'Boise State'),'Team']= 'Boise St.'
Final.loc[(Final.Team == 'Ohio State'),'Team']= 'Ohio St.'
Final.loc[(Final.Team == 'Florida Intl'),'Team']= 'FIU'
Final.loc[(Final.Team == 'W Michigan'),'Team']= 'Western Michigan'
Final.loc[(Final.Team == 'Rob Morris'),'Team']= 'Robert Morris'
Final.loc[(Final.Team == 'Ark Pine Bl'),'Team']= 'Arkansas Pine Bluff'
Final.loc[(Final.Team == 'LA Monroe'),'Team']= 'Louisiana Monroe'
Final.loc[(Final.Team == 'S Methodist'),'Team']= 'Southern Methodist'
Final.loc[(Final.Team == 'Cleveland St'),'Team']= 'Cleveland St.'
Final.loc[(Final.Team == 'Kennesaw St'),'Team']= 'Kennesaw St.'
Final.loc[(Final.Team == 'James Mad'),'Team']= 'James Madison'
Final.loc[(Final.Team == 'Oklahoma St'),'Team']= 'Oklahoma St.'
Final.loc[(Final.Team == 'N Kentucky'),'Team']= 'Northern Kentucky'
Final.loc[(Final.Team == 'St Fran (PA)'),'Team']= 'St. Francis PA'
Final.loc[(Final.Team == 'S Carolina'),'Team']= 'South Carolina'
Final.loc[(Final.Team == 'Southern Methodist'),'Team']= 'SMU'
Final.loc[(Final.Team == 'Penn State'),'Team']= 'Penn St.'
Final.loc[(Final.Team == 'Florida St'),'Team']= 'Florida St.'
Final.loc[(Final.Team == 'N Dakota St'),'Team']= 'North Dakota St.'
Final.loc[(Final.Team == 'Weber State'),'Team']= 'Weber St.'
Final.loc[(Final.Team == 'VA Military'),'Team']= 'VMI'
Final.loc[(Final.Team == 'Nicholls St'),'Team']= 'Nicholls St.'
Final.loc[(Final.Team == 'SE Missouri'),'Team']= 'Southeast Missouri St.'
Final.loc[(Final.Team == 'Geo Mason'),'Team']= 'George Mason'
Final.loc[(Final.Team == 'Idaho State'),'Team']= 'Idaho St.'
Final.loc[(Final.Team == 'Loyola Mymt'),'Team']= 'Loyola Marymount'
Final.loc[(Final.Team == 'UCSB'),'Team']= 'UC Santa Barbara'
Final.loc[(Final.Team == 'S Mississippi'),'Team']= 'Southern Miss'
Final.loc[(Final.Team == 'S Utah'),'Team']= 'Southern Utah'
Final.loc[(Final.Team == 'Mt St Marys'),'Team']= "Mount St. Mary's"
Final.loc[(Final.Team == 'F Dickinson'),'Team']= 'Fairleigh Dickinson'
Final.loc[(Final.Team == 'W Carolina'),'Team']= 'Western Carolina'
Final.loc[(Final.Team == 'Jackson St'),'Team']= 'Jackson St.'
Final.loc[(Final.Team == 'Wichita St'),'Team']= 'Wichita St.'
Final.loc[(Final.Team == 'E Washingtn'),'Team']= 'Eastern Washington'
Final.loc[(Final.Team == 'NC Central'),'Team']= 'North Carolina Central'
Final.loc[(Final.Team == 'Georgia St'),'Team']= 'Georgia St.'
Final.loc[(Final.Team == 'Kent State'),'Team']= 'Kent St.'
Final.loc[(Final.Team == 'Prairie View'),'Team']= 'Prairie View A&M'
Final.loc[(Final.Team == 'AR Lit Rock'),'Team']= 'Little Rock'
Final.loc[(Final.Team == 'Incar Word'),'Team']= 'Incarnate Word'
Final.loc[(Final.Team == 'NC-Grnsboro'),'Team']= 'UNC Greensboro'
Final.loc[(Final.Team == 'Bowling Grn'),'Team']= 'Bowling Green'
Final.loc[(Final.Team == 'W Illinois'),'Team']= 'Western Illinois'
Final.loc[(Final.Team == 'St Marys'),'Team']= "Saint Mary's"
Final.loc[(Final.Team == 'TN Martin'),'Team']= 'Tennessee Martin'
Final.loc[(Final.Team == 'Miss State'),'Team']= 'Mississippi St.'
Final.loc[(Final.Team == 'Maryland ES'),'Team']= 'Maryland Eastern Shore'
Final.loc[(Final.Team == 'Gard-Webb'),'Team']= 'Gardner Webb'
Final.loc[(Final.Team == 'Central Ark'),'Team']= 'Central Arkansas'
Final.loc[(Final.Team == 'TN State'),'Team']= 'Tennessee St.'
Final.loc[(Final.Team == 'S Illinois'),'Team']= 'Southern Illinois'
Final.loc[(Final.Team == 'Alab A&M'),'Team']= 'Alabama A&M'
Final.loc[(Final.Team == 'TX Christian'),'Team']= 'TCU'
Final.loc[(Final.Team == 'St Fran (NY)'),'Team']= 'St. Francis NY'
Final.loc[(Final.Team == 'Central Mich'),'Team']= 'Central Michigan'
Final.loc[(Final.Team == 'Boston U'),'Team']= 'Boston University'
Final.loc[(Final.Team == 'N Carolina'),'Team']= 'North Carolina'
Final.loc[(Final.Team == 'Loyola-Chi'),'Team']= 'Loyola Chicago'
Final.loc[(Final.Team == 'Alabama St'),'Team']= 'Alabama St.'
Final.loc[(Final.Team == 'CS Fullerton'),'Team']= 'Cal St. Fullerton'
Final.loc[(Final.Team == 'Ball State'),'Team']= 'Ball St.'

# %%
a = Games['Home'].tolist()
b = Games['Away'].tolist()
c = Games['Home_Pt_Diff'].tolist()

# %%
Update = pd.DataFrame()
for i,j,z in zip(a,b,c):
    H1 = i
    A1 = j
    S11 = z
    M = Final[Final['Team'].isin([H1, A1])]
    G = M.copy()
    for x in G.columns:
        G[x] = G[x].astype(str)
        G[x] = G[x].str.replace('%', '')
        G[x] = G[x].str.replace('--', '0')
    HomeRow1 = G.loc[G['Team'] == H1]
    AwayRow1 = G.loc[G['Team'] == A1]
    c = HomeRow1.values.flatten().tolist()
    d = AwayRow1.values.flatten().tolist()
    FirstRow1 = c + d + [S11]
    F = pd.DataFrame(FirstRow1).T
    Update = Update.append(F)

Columns = Final.columns.tolist()
HomeColumns = []
AwayColumns = []
for x in Columns:
    x = 'Home_' + x
    HomeColumns.append(x)
for x in Columns:
    x = 'Away_' + x
    AwayColumns.append(x)

AllColumns = HomeColumns + AwayColumns + ['Home_Win/Lose_Pt']
Update.columns = AllColumns

# %%
Update
# Out:
#              Home_Team  Home_TurnAst_Last3   Home_TurnAst_Home  \
# 0           Oregon St.  0.5920000000000001  1.1079999999999999
# 0           Washington               0.703  0.6629999999999999
# 0           Fresno St.               1.031               1.193
# 0              Wyoming               1.133               1.186
# 0           Texas Tech  0.8079999999999999               1.175
# 0             Southern               0.976               1.008
# 0     Prairie View A&M               0.872               1.014
# 0                Texas               0.789               1.216
# 0       Texas Southern               0.674               0.971
# 0        Grambling St.               0.711               1.055
# 0                 Iowa                 1.5  1.8630000000000002
# 0          Norfolk St.                 1.0                 1.1
# 0               Howard               0.846               0.924
# 0           Coppin St.  0.7609999999999999               0.764
# ...

# %%
Update.to_csv('CapstoneGames.csv', mode='a')
